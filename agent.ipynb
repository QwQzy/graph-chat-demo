# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.abspath(".")))

from IPython.display import Image, display
from database.mongodb_client import get_mongo_client
from agent.agent_builder import create_chat_agent

local_agent = create_chat_agent(get_mongo_client())
display(Image(local_agent.get_graph(xray=True).draw_mermaid_png()))
